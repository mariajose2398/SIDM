# %%
print("Importing----")

import os, sys, time, subprocess, tempfile
from coffea import processor
import coffea.util
import matplotlib.pyplot as plt
import yaml

sidm_path = str(os.getcwd()).split('/sidm')[0]
if sidm_path not in sys.path:
    sys.path.insert(1, sidm_path)

from sidm.tools import utilities, scaleout, sidm_processor, llpnanoaodschema
from sidm.studies.cosmicVeto import functions
utilities.set_plot_style()
# %matplotlib inline
import mplhep as hep


print("----Files----")

yaml_file_path = '../../configs/ntuples/signal_4mu_v10.yaml'
# Open and read the YAML file
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)
signals_all = list(data["llpNanoAOD_v2"]["samples"].keys())


data = functions.get_data_files()

print(data)



bgs= [
    
     "TTJets",
    "DYJetsToMuMu_M10to50",
      
         "QCD_Pt1000",
      # "QCD_Pt800To1000", #failed

      "QCD_Pt600To800",
       "QCD_Pt470To600",
        "QCD_Pt300To470",
     
      "QCD_Pt170To300",
         "QCD_Pt120To170",
 "DYJetsToMuMu_M50",
        "QCD_Pt80To120",
         "QCD_Pt50To80",
       "QCD_Pt30To50",
       "QCD_Pt20To30", #error
         "QCD_Pt15To20", #error
 
 
      "DYJetsToMuMu_M10to50",
       "DYJetsToMuMu_M50",
     
]

print("========Runner=======")

runner = processor.Runner(
    executor=processor.IterativeExecutor(),
    # executor=processor.DaskExecutor(client=client),
    schema = llpnanoaodschema.LLPNanoAODSchema,
    skipbadfiles=True,
)
channel_name = "cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp"
hist_collection = "dsaMuon_base"
print("=======Processor=========")

p = sidm_processor.SidmProcessor([channel_name], [hist_collection],verbose=True)


print("========Fileset========")
max_files_bg = -1
max_files_data =2
max_files_signal = 1

fileset = utilities.make_fileset([data[0]], "llpNanoAOD_v2",
             max_files=max_files_data,location_cfg="data_skimmed.yaml")
output = runner.run(fileset, treename="Events", processor_instance=p)

# fileset = utilities.make_fileset(signals_all[0], "llpNanoAOD_v2", max_files=max_files_signal, location_cfg="signal_4mu_v10.yaml")
# output= runner.run(fileset, treename="Events", processor_instance=p)

# fileset = utilities.make_fileset(bgs, "skimmed_llpNanoAOD_v2", location_cfg="backgrounds.yaml", max_files=max_files_bg)
# output = runner.run(fileset, treename="Events", processor_instance=p)
# Out:
# Importing----
# ----Files----
# ['DoubleMuon_2018C', 'DoubleMuon_2018A_0', 'DoubleMuon_2018A_1', 'DoubleMuon_2018A_2', 'DoubleMuon_2018B_0', 'DoubleMuon_2018B_1', 'DoubleMuon_2018B_2', 'DoubleMuon_2018B_3', 'DoubleMuon_2018B_4', 'DoubleMuon_2018B_5', 'DoubleMuon_2018B_6', 'DoubleMuon_2018B_7', 'DoubleMuon_2018B_8', 'DoubleMuon_2018B_9', 'DoubleMuon_2018B_10', 'DoubleMuon_2018B_11', 'DoubleMuon_2018B_12', 'DoubleMuon_2018B_13', 'DoubleMuon_2018D_0', 'DoubleMuon_2018D_1', 'DoubleMuon_2018D_10', 'DoubleMuon_2018D_11', 'DoubleMuon_2018D_12', 'DoubleMuon_2018D_13', 'DoubleMuon_2018D_14', 'DoubleMuon_2018D_15', 'DoubleMuon_2018D_16', 'DoubleMuon_2018D_17', 'DoubleMuon_2018D_18', 'DoubleMuon_2018D_19', 'DoubleMuon_2018D_2', 'DoubleMuon_2018D_20', 'DoubleMuon_2018D_21', 'DoubleMuon_2018D_22', 'DoubleMuon_2018D_23', 'DoubleMuon_2018D_24', 'DoubleMuon_2018D_25', 'DoubleMuon_2018D_26', 'DoubleMuon_2018D_27', 'DoubleMuon_2018D_28', 'DoubleMuon_2018D_29', 'DoubleMuon_2018D_3', 'DoubleMuon_2018D_30', 'DoubleMuon_2018D_31', 'DoubleMuon_2018D_32', 'DoubleMuon_2018D_33', 'DoubleMuon_2018D_34', 'DoubleMuon_2018D_35', 'DoubleMuon_2018D_36', 'DoubleMuon_2018D_37', 'DoubleMuon_2018D_38', 'DoubleMuon_2018D_39', 'DoubleMuon_2018D_4', 'DoubleMuon_2018D_40', 'DoubleMuon_2018D_41', 'DoubleMuon_2018D_42', 'DoubleMuon_2018D_43', 'DoubleMuon_2018D_44', 'DoubleMuon_2018D_45', 'DoubleMuon_2018D_46', 'DoubleMuon_2018D_47', 'DoubleMuon_2018D_48', 'DoubleMuon_2018D_49', 'DoubleMuon_2018D_5', 'DoubleMuon_2018D_6', 'DoubleMuon_2018D_7', 'DoubleMuon_2018D_8', 'DoubleMuon_2018D_9']
# ========Runner=======
# =======Processor=========
# ========Fileset========
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# Applying 2018 Golden JSON: 0 events removed
# Warning: weight not found in this sample. Skipping.
# Warning: gens not found in this sample. Skipping.
# Warning: genMus not found in this sample. Skipping.
# Warning: genEs not found in this sample. Skipping.
# Warning: genAs not found in this sample. Skipping.
# Warning: genAs_toMu not found in this sample. Skipping.
# Warning: genAs_toE not found in this sample. Skipping.
# Applying cuts to the nested muons collection
# Applying cuts to the nested dsaMuons collection
# Warning: Unable to apply all for nested dsaMuons collection. Skipping.... no field named 'good_matched_muons'
# Applying electrons pT > 10 GeV
# Applying electrons |eta| < 2.4
# Applying electrons MVANonIsoWPL
# Applying electrons missing_hits >= 1
# Applying muons looseID
# Applying muons pT > 5 GeV
# Applying muons |eta| < 2.4
# Applying muons trkNumPixelHits <= 2
# Applying photons pT > 20 GeV
# Applying photons |eta| < 2.5
# Applying photons Custom Cutbased
# Applying photons pixelSeed
# Applying photons Photon DR Veto 0p025
# Applying dsaMuons pT > 10 GeV
# Applying dsaMuons |eta| < 2.4
# Applying dsaMuons displaced ID
# Applying dsaMuons all
# Applying ljs pT > 30 GeV
# Applying ljs |eta| < 2.4
# Applying mu_ljs Mu >= 2
# Applying mu_ljs dzSpread_mu <= 50
# Applying mu_ljs dxySpread_mu <= 50
# Applying mu_ljs dzSpread_pf <= 10
# Applying mu_ljs dxySpread_pf <= 10
# Applying cut: pass triggers
# Applying cut: PV filter
# Applying cut: >=2 muons (pf or dsa) pT > 26 GeV
# Applying cut: pass flags
# Applying cut: = 1 muLj or 1 egmLJ
# Applying cut: all cosAlpha(mu, mu) > -0.99
# Warning: cannot fill counter Gen As to muons. Skipping.
# Warning: cannot fill counter Gen As to electrons. Skipping.
# Warning: cannot fill counter Matched gen As to muons. Skipping.
# Warning: cannot fill counter Matched gen As to electrons. Skipping.
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /usr/local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing
# cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# Applying 2018 Golden JSON: 0 events removed
# Warning: weight not found in this sample. Skipping.
# Warning: gens not found in this sample. Skipping.
# Warning: genMus not found in this sample. Skipping.
# Warning: genEs not found in this sample. Skipping.
# Warning: genAs not found in this sample. Skipping.
# Warning: genAs_toMu not found in this sample. Skipping.
# Warning: genAs_toE not found in this sample. Skipping.
# Applying cuts to the nested muons collection
# Applying cuts to the nested dsaMuons collection
# Warning: Unable to apply all for nested dsaMuons collection. Skipping.... no field named 'good_matched_muons'
# Applying electrons pT > 10 GeV
# Applying electrons |eta| < 2.4
# Applying electrons MVANonIsoWPL
# Applying electrons missing_hits >= 1
# Applying muons looseID
# Applying muons pT > 5 GeV
# Applying muons |eta| < 2.4
# Applying muons trkNumPixelHits <= 2
# Applying photons pT > 20 GeV
# Applying photons |eta| < 2.5
# Applying photons Custom Cutbased
# Applying photons pixelSeed
# Applying photons Photon DR Veto 0p025
# Applying dsaMuons pT > 10 GeV
# Applying dsaMuons |eta| < 2.4
# Applying dsaMuons displaced ID
# Applying dsaMuons all
# Applying ljs pT > 30 GeV
# Applying ljs |eta| < 2.4
# Applying mu_ljs Mu >= 2
# Applying mu_ljs dzSpread_mu <= 50
# Applying mu_ljs dxySpread_mu <= 50
# Applying mu_ljs dzSpread_pf <= 10
# Applying mu_ljs dxySpread_pf <= 10
# Applying cut: pass triggers
# Applying cut: PV filter
# Applying cut: >=2 muons (pf or dsa) pT > 26 GeV
# Applying cut: pass flags
# Applying cut: = 1 muLj or 1 egmLJ
# Applying cut: all cosAlpha(mu, mu) > -0.99
# Warning: cannot fill counter Gen As to muons. Skipping.
# Warning: cannot fill counter Gen As to electrons. Skipping.
# Warning: cannot fill counter Matched gen As to muons. Skipping.
# Warning: cannot fill counter Matched gen As to electrons. Skipping.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# DoubleMuon_2018C is data. Not scaling histograms or cutflows.

# %%
print(output["out"])
# Out:
# {'DoubleMuon_2018C': {'cutflow': {'cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp': <sidm.tools.cutflow.SimpleCutflow object at 0x7f4a4fbc5d60>}, 'hists': {'dsaMuon_n': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(10, 0, 10, name='dsaMuons_n', label='Number of DSA Muons'),
#   storage=Weight()) # Sum: WeightedSum(value=567, variance=567), 'dsaMuon_pt': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(100, 0, 500, name='dsaMuons_pt', label='DSA Muon $p_T$ (GeV)'),
#   storage=Weight()) # Sum: WeightedSum(value=1045, variance=1045) (WeightedSum(value=1046, variance=1046) with flow), 'dsaMuon_dxy': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(100, 0, 100, name='dsaMuons_dxy', label='DSA Muon $d_0$'),
#   storage=Weight()) # Sum: WeightedSum(value=526, variance=526) (WeightedSum(value=1046, variance=1046) with flow), 'dsaMuon_dz': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(300, 0, 300, name='$DSA $\\mu$ dz (cm)'),
#   storage=Weight()) # Sum: WeightedSum(value=1046, variance=1046), 'dsaMuon_eta_phi': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(50, -3, 3, name='dsaMuons_eta', label='DSA Muon $\\eta$'),
#   Regular(50, -3.14159, 3.14159, name='dsaMuons_phi', label='DSA Muon $\\phi$'),
#   storage=Weight()) # Sum: WeightedSum(value=1046, variance=1046), 'dsaMuon_absD0': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(100, 0, 500, name='dsaMuons_dxy', label='DSA Muon |$d_0$|'),
#   storage=Weight()) # Sum: WeightedSum(value=1046, variance=1046), 'dsaMuon_absD0_lowRange': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(100, 0, 10, name='dsaMuons_dxy', label='DSA Muon |$d_0$|'),
#   storage=Weight()) # Sum: WeightedSum(value=915, variance=915) (WeightedSum(value=1046, variance=1046) with flow), 'dsaMuon_numOverlapSegments_matchedMuons': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(10, 0, 10, name='dsaMuon_numOverlapSegments_matchedMuons'),
#   storage=Weight()) # Sum: WeightedSum(value=1046, variance=1046), 'dsaMuon_numOverlapSegments_goodMatchedMuons': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(10, 0, 10, name='dsaMuon_numOverlapSegments_goodMatchedMuons'),
#   storage=Weight()) # Sum: WeightedSum(value=144, variance=144), 'dsaMu_dsaMu_dR': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(50, 0, 1, name='genMu_genMu_dR', label='$\\Delta R$(DSA $\\mu_0$, DSA $\\mu_1$)'),
#   storage=Weight()) # Sum: WeightedSum(value=423, variance=423) (WeightedSum(value=463, variance=463) with flow), 'dsaMu_dsaMu_invmass': Hist(
#   StrCategory(['cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp'], name='channel'),
#   Regular(200, 0, 1000, name='muon_muon_mass', label='Invariant Mass (DSA $\\mu_{0}$, DSA $\\mu_{1}$)'),
#   storage=Weight()) # Sum: WeightedSum(value=463, variance=463)}, 'counters': {'0.4': {'cr_1egmOr1mu_lj_withoutEta_phi_cosmic_veto_disp': {'Total LJs': np.int64(617)}}}, 'metadata': {'n_evts': 45908, 'scaled_sum_weights': np.float64(111992.8228176618), 'year': set_accumulator({'2018'}), 'is_data': set_accumulator({True}), 'unweighted_hist': set_accumulator({False}), 'n_removed_golden_json': 0}}}

# %%
print("=======Plotting=======")
# histogram1 = output["out"][S[0]]["hists"]["muon_dz_innerVz_diff"][channelname,:]
histogram1 = output["out"][data[0]]["hists"]["dsaMuon_eta_phi"][channel_name,:, :]
# histogram1 = output["out"][bgs[0]]["hists"]["mu_lj_vyzSpread_pf"][channel_name,:]

utilities.plot(histogram1)
# Out:
# =======Plotting=======
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f4a4aeb8260>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f4a4aeb8f20>, text=[])
