# %%
pip install -U mplhep
# Out:
# Requirement already satisfied: mplhep in /usr/local/lib/python3.12/site-packages (1.3.3)
# Requirement already satisfied: matplotlib>=3.11.1 in /usr/local/lib/python3.12/site-packages (from mplhep) (3.11.1)
# Requirement already satisfied: mplhep-data>=0.0.4 in /usr/local/lib/python3.12/site-packages (from mplhep) (0.0.5)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/site-packages (from mplhep) (2.3.5)
# Requirement already satisfied: uhi>=0.2.0 in /usr/local/lib/python3.12/site-packages (from mplhep) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (25.0)
# Requirement already satisfied: pillow>=9 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/site-packages (from matplotlib>=3.11.1->mplhep) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.11.1->mplhep) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, sys
sidm_path = str(os.getcwd()).split('/sidm')[0]
if sidm_path not in sys.path:
    sys.path.insert(1, sidm_path)
from sidm.tools import utilities #scaleout, sidm_processor, llpnanoaodschema
from sidm.studies.cosmicVeto import functions
utilities.set_plot_style()

# %%
title = "1 LJ CR + CosAlpha"
ratio = 1
channel_name= "cr_1egmOr1mu_lj_CosMu"
TT = functions.get_bg_file_names("TTJets")
DY = functions.get_bg_file_names("DYJetsToLL")
QCD = functions.get_bg_file_names("QCD")
DB = functions.get_bg_file_names("Diboson")
data = functions.get_data_files()   
folder_name = f"OutputFiles/{channel_name}"
sum_data_all= utilities.sum_hist(data, folder_name)
summed_QCD = utilities.sum_hist(QCD, folder_name)
summed_TT  = utilities.sum_hist(TT,  folder_name)
summed_DY  = utilities.sum_hist(DY, folder_name)
summed_DB  = utilities.sum_hist(DB,  folder_name)

# %%
histogram_list  = [ 
"egm_lj_pt",
 "mu_lj_pt",
]
functions.plot_DataMC(histogram_list,channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=2j, file_name=f"{channel_name}_lj_pt")

histogram_list  = [ 
"mu_lj_muon_pt",
 "mu_lj_pfMuon_pt",
    "mu_lj_dsaMuon_pt",
]
functions.plot_DataMC(histogram_list,channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=2j, file_name=f"{channel_name}_muonPt")

histogram_list  = [ 
"mu_lj_muonN",
 "mu_lj_pfMu_n",
    "mu_lj_dsaMu_n",


]

functions.plot_DataMC(histogram_list, channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=1j, file_name = f"{channel_name}_muonN")


histogram_list  = [ 
# "cosAlpha_mu",
#  "cosAlpha_pf",
    "cosAlpha_dsa",
]
functions.plot_DataMC(histogram_list,channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=4j, file_name = f"{channel_name}_cosAlpha")

histogram_list=['cosAlpha_dsa']

functions.plot_DataMC(histogram_list, channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=1j, file_name = f"{channel_name}_cosAlpha_smallrange", ranges = [-1j, -0.75j])


histogram_list  = [ 
"mu_lj_dzSpread_pf",
 "mu_lj_vxySpread_pf",
]
functions.plot_DataMC(histogram_list,channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=2j, file_name=f"{channel_name}_dataLjSpreadpf")

histogram_list  = [ 
"mu_lj_dzSpread_mu",
 "mu_lj_vxySpread_mu",
]
functions.plot_DataMC(histogram_list,channel_name, summed_QCD, summed_TT, summed_DY, summed_DB, sum_data_all, ratio, binning=2j, file_name=f"{channel_name}_dataLjSpreadmu")
# Out:
# egm_lj_pt
# mu_lj_pt
# mu_lj_muon_pt
# mu_lj_pfMuon_pt
# mu_lj_dsaMuon_pt
# mu_lj_muonN
# mu_lj_pfMu_n
# mu_lj_dsaMu_n
# cosAlpha_dsa
# cosAlpha_dsa
# mu_lj_dzSpread_pf
# mu_lj_vxySpread_pf
# mu_lj_dzSpread_mu
# mu_lj_vxySpread_mu
