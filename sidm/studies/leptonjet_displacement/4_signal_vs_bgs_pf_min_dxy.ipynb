# %%
# python
import os
import sys
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local
sidm_path = str(os.getcwd()).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout, llpnanoaodschema
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
from hist import intervals
import coffea.util
# import numpy as np
import mplhep as hep

# %%
import yaml
yaml_file_path = '../../configs/ntuples/signal_2mu2e_v10.yaml'
# Open and read the YAML file
with open(yaml_file_path, 'r') as file:
    data = yaml.safe_load(file)
signals_all = list(data["llpNanoAOD_v2"]["samples"].keys())
for x in range(len(signals_all)):
    print("'" + signals_all[x] + "',")
# Out:
# '2Mu2E_100GeV_0p25GeV_0p02mm',
# '2Mu2E_100GeV_0p25GeV_0p2mm',
# '2Mu2E_100GeV_0p25GeV_2p0mm',
# '2Mu2E_100GeV_0p25GeV_10p0mm',
# '2Mu2E_100GeV_0p25GeV_20p0mm',
# '2Mu2E_100GeV_1p2GeV_0p096mm',
# '2Mu2E_100GeV_1p2GeV_0p96mm',
# '2Mu2E_100GeV_1p2GeV_9p6mm',
# '2Mu2E_100GeV_1p2GeV_48p0mm',
# '2Mu2E_100GeV_1p2GeV_96p0mm',
# '2Mu2E_100GeV_5p0GeV_0p4mm',
# '2Mu2E_100GeV_5p0GeV_4p0mm',
# '2Mu2E_100GeV_5p0GeV_40p0mm',
# '2Mu2E_100GeV_5p0GeV_200mm',
# '2Mu2E_100GeV_5p0GeV_400mm',
# '2Mu2E_150GeV_0p25GeV_0p013mm',
# '2Mu2E_150GeV_0p25GeV_0p13mm',
# '2Mu2E_150GeV_0p25GeV_1p3mm',
# '2Mu2E_150GeV_0p25GeV_6p7mm',
# '2Mu2E_150GeV_0p25GeV_13p0mm',
# '2Mu2E_150GeV_1p2GeV_0p064mm',
# '2Mu2E_150GeV_1p2GeV_0p64mm',
# '2Mu2E_150GeV_1p2GeV_6p4mm',
# '2Mu2E_150GeV_1p2GeV_32p0mm',
# '2Mu2E_150GeV_1p2GeV_64p0mm',
# '2Mu2E_150GeV_5p0GeV_0p27mm',
# '2Mu2E_150GeV_5p0GeV_2p7mm',
# '2Mu2E_150GeV_5p0GeV_27p0mm',
# '2Mu2E_150GeV_5p0GeV_130p0mm',
# '2Mu2E_150GeV_5p0GeV_270p0mm',
# '2Mu2E_200GeV_0p25GeV_0p01mm',
# '2Mu2E_200GeV_0p25GeV_0p1mm',
# '2Mu2E_200GeV_0p25GeV_1p0mm',
# '2Mu2E_200GeV_0p25GeV_5p0mm',
# '2Mu2E_200GeV_0p25GeV_10p0mm',
# '2Mu2E_200GeV_1p2GeV_0p048mm',
# '2Mu2E_200GeV_1p2GeV_0p48mm',
# '2Mu2E_200GeV_1p2GeV_4p8mm',
# '2Mu2E_200GeV_1p2GeV_24p0mm',
# '2Mu2E_200GeV_1p2GeV_48p0mm',
# '2Mu2E_200GeV_5p0GeV_0p2mm',
# '2Mu2E_200GeV_5p0GeV_2p0mm',
# '2Mu2E_200GeV_5p0GeV_20p0mm',
# '2Mu2E_200GeV_5p0GeV_100p0mm',
# '2Mu2E_200GeV_5p0GeV_200p0mm',
# '2Mu2E_500GeV_0p25GeV_0p004mm',
# '2Mu2E_500GeV_0p25GeV_0p04mm',
# '2Mu2E_500GeV_0p25GeV_0p4mm',
# '2Mu2E_500GeV_0p25GeV_2p0mm',
# '2Mu2E_500GeV_0p25GeV_4p0mm',
# '2Mu2E_500GeV_1p2GeV_0p019mm',
# '2Mu2E_500GeV_1p2GeV_0p19mm',
# '2Mu2E_500GeV_1p2GeV_1p9mm',
# '2Mu2E_500GeV_1p2GeV_9p6mm',
# '2Mu2E_500GeV_1p2GeV_19p0mm',
# '2Mu2E_500GeV_5p0GeV_0p08mm',
# '2Mu2E_500GeV_5p0GeV_0p8mm',
# '2Mu2E_500GeV_5p0GeV_8p0mm',
# '2Mu2E_500GeV_5p0GeV_40p0mm',
# '2Mu2E_500GeV_5p0GeV_80p0mm',
# '2Mu2E_800GeV_0p25GeV_0p0025mm',
# '2Mu2E_800GeV_0p25GeV_0p025mm',
# '2Mu2E_800GeV_0p25GeV_0p25mm',
# '2Mu2E_800GeV_0p25GeV_1p2mm',
# '2Mu2E_800GeV_0p25GeV_2p5mm',
# '2Mu2E_800GeV_1p2GeV_0p012mm',
# '2Mu2E_800GeV_1p2GeV_0p12mm',
# '2Mu2E_800GeV_1p2GeV_1p2mm',
# '2Mu2E_800GeV_1p2GeV_6p0mm',
# '2Mu2E_800GeV_1p2GeV_12p0mm',
# '2Mu2E_800GeV_5p0GeV_0p05mm',
# '2Mu2E_800GeV_5p0GeV_0p5mm',
# '2Mu2E_800GeV_5p0GeV_5p0mm',
# '2Mu2E_800GeV_5p0GeV_25p0mm',
# '2Mu2E_800GeV_5p0GeV_50p0mm',
# '2Mu2E_1000GeV_0p25GeV_0p002mm',
# '2Mu2E_1000GeV_0p25GeV_0p02mm',
# '2Mu2E_1000GeV_0p25GeV_0p2mm',
# '2Mu2E_1000GeV_0p25GeV_1p0mm',
# '2Mu2E_1000GeV_0p25GeV_2p0mm',
# '2Mu2E_1000GeV_1p2GeV_0p0096mm',
# '2Mu2E_1000GeV_1p2GeV_0p096mm',
# '2Mu2E_1000GeV_1p2GeV_0p96mm',
# '2Mu2E_1000GeV_1p2GeV_4p8mm',
# '2Mu2E_1000GeV_1p2GeV_9p6mm',
# '2Mu2E_1000GeV_5p0GeV_0p04mm',
# '2Mu2E_1000GeV_5p0GeV_0p4mm',
# '2Mu2E_1000GeV_5p0GeV_4p0mm',
# '2Mu2E_1000GeV_5p0GeV_20p0mm',
# '2Mu2E_1000GeV_5p0GeV_40p0mm',

# %%
S  = [
'2Mu2E_500GeV_5p0GeV_0p8mm', 
'2Mu2E_500GeV_5p0GeV_80p0mm',
'2Mu2E_500GeV_0p25GeV_0p004mm',
'2Mu2E_500GeV_0p25GeV_4p0mm',
]
output_signal = coffea.util.load( "output_signal_base_ljObjCut_ljIso_2lj.coffea" )
output_signal["out"]["2Mu2E_500GeV_5p0GeV_0p8mm"]
# Out:
# {'cutflow': {'base_ljObjCut_ljIso_2lj': <sidm.tools.cutflow.Cutflow at 0x7fafbed48b90>},
#  'hists': {'mulj_egmlj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'mulj_egmlj_invmass_pixelHits_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.02262, variance=0.000321175),
#   'mulj_egmlj_invmass_trkLayers_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.427765, variance=0.000134349),
#   '1pf_mulj_egmlj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=16.904, variance=0.00530905),
#   'pf_mulj_egmlj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5007, variance=0.0051824),
#   'pf_dsa_mulj_egmlj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'dsa_mulj_egmlj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.00345479, variance=1.08505e-06),
#   '1pf_mulj_egmlj_invmass_pixelHits2': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=3.32382, variance=0.00104392),
#   '1pf_mulj_egmlj_invmass_pixelHits1': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.10051, variance=0.000345638),
#   '1pf_mulj_egmlj_invmass_pixelHits0': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.295227, variance=9.27225e-05),
#   '1pf_mulj_egmlj_invmass_pixelHits3': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=8.1555, variance=0.00256141),
#   '1pf_mulj_egmlj_invmass_pixelHits4': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=14.2215, variance=0.00446656),
#   '1pf_mulj_egmlj_invmass_trkLayers10': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.41898, variance=0.00044566),
#   '1pf_mulj_egmlj_invmass_trkLayers12': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=7.15141, variance=0.00224605),
#   '1pf_mulj_egmlj_invmass_trkLayers11': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=3.49687, variance=0.00109827),
#   '1pf_mulj_egmlj_invmass_trkLayers9': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.463256, variance=0.000145495),
#   '1pf_mulj_egmlj_invmass_trkLayers8': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.116206, variance=3.64971e-05),
#   '1pf_mulj_egmlj_invmass_trkLayers7': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.0273242, variance=8.58176e-06),
#   'pf_mulj_egmlj_invmass_pixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=3.08858, variance=0.000970035),
#   'pf_dsa_mulj_egmlj_invmass_pixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.23524, variance=7.38821e-05),
#   'pf_mulj_egmlj_invmass_trkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.27199, variance=0.000399496),
#   'pf_dsa_mulj_egmlj_invmass_trkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.146985, variance=4.6164e-05),
#   'mulj_1e_lj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=15.7705, variance=0.00495306),
#   'mulj_1e_lj_invmass_lostHits1': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=5.1357, variance=0.00161298),
#   'mulj_1e_lj_invmass_lostHits0': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=15.7705, variance=0.00495306),
#   'mulj_1e_lj_invmass_lostHits2': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.10113, variance=0.000345835),
#   'mulj_e_lj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=13.6904, variance=0.00429976),
#   'mulj_eg_lj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=2.0801, variance=0.000653299),
#   'mulj_g_lj_invmass': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.13694, variance=0.00035708),
#   'mulj_e_lj_invmass_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=3.80341, variance=0.00119454),
#   'mulj_eg_lj_invmass_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 1200, name='ljlj_mass', label='Invariant Mass ($LJ_{0}$, $LJ_{1}$)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.33229, variance=0.000418435),
#   'mu_lj_n': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='mu_ljs_n', label='Number of $\\mu$-type Lepton Jets'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'egm_lj_n': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='egm_ljs_n', label='Number of $e\\gamma$-type Lepton Jets'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'egm_lj_electron_dxy_XXXLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='egm- type LJ e dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=21.0711, variance=0.00661782) (WeightedSum(value=22.1577, variance=0.00695912) with flow),
#   'egm_lj_electron_max_dxy_XXXLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='egm- type LJ e max dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=14.719, variance=0.00462281) (WeightedSum(value=15.7834, variance=0.0049571) with flow),
#   'egm_lj_electron_min_dxy_XXXLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='egm- type LJ e min dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=15.1995, variance=0.00477373) (WeightedSum(value=15.7834, variance=0.0049571) with flow),
#   'eLj_electron_min_dxy_XXXLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='e LJ e min  dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=13.3901, variance=0.00420546) (WeightedSum(value=13.702, variance=0.00430341) with flow),
#   'egLj_electron_min_dxy_XXXLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='eg LJ e min dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=1.80937, variance=0.00056827) (WeightedSum(value=2.08135, variance=0.000653693) with flow),
#   'egm_lj_electron_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='egm- type LJ e lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=22.1577, variance=0.00695912),
#   'eLj_electron_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='eLJ e lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=19.9724, variance=0.00627277),
#   'egLj_electron_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='eg LJ e lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=2.18531, variance=0.000686344),
#   'electron_n': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='electrons_n', label='Number of Electrons'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'egm_lj_iso': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(50, 0, 1, name='egm_ljs_isolation', label='$e\\gamma$-type Lepton Jet isolation'),
#     storage=Weight()) # Sum: WeightedSum(value=16.958, variance=0.00532602) (WeightedSum(value=16.9957, variance=0.00533786) with flow),
#   'egm_lj_electronN': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='egm_ljs_electron_n', label='$e\\gamma$-type Lepton Jet electron_n'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9957, variance=0.00533786),
#   'egm_lj_photonN': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='egm_ljs_photon_n', label='$e\\gamma$-type Lepton Jet photon_n'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9957, variance=0.00533786),
#   'egm_lj_electron_min_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='egm- type LJ e min lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=15.7834, variance=0.0049571),
#   'eLj_electron_min_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='eLJ e min lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=13.702, variance=0.00430341),
#   'leading_egm_lj_electron_min_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='Leading egm- type LJ e min lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=15.7705, variance=0.00495306),
#   'leading_e_lj_electron_min_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='Leading e- type LJ e min lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=13.6904, variance=0.00429976),
#   'leading_eg_lj_electron_min_lostHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='Leading eg- type LJ e min lostHits'),
#     storage=Weight()) # Sum: WeightedSum(value=2.0801, variance=0.000653299),
#   'mu_lj_pfMuon_dxy_XLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='$\\mu$- type LJ PF $\\mu$ dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=27.8085, variance=0.00873387) (WeightedSum(value=33.4549, variance=0.0105072) with flow),
#   'mu_lj_pfMuon_max_dxy_XLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='$\\mu$- type LJ PF $\\mu$ max dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=12.1442, variance=0.00381415) (WeightedSum(value=16.9049, variance=0.00530935) with flow),
#   'mu_lj_pfMuon_min_dxy_XLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='$\\mu$- type LJ PF $\\mu$ min dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=15.9536, variance=0.00501056) (WeightedSum(value=16.9049, variance=0.00530935) with flow),
#   'pf_mu_lj_pfMuon_min_dxy_XLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='PF $\\mu$- type LJ PF $\\mu$ min dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=15.6185, variance=0.00490531) (WeightedSum(value=16.5016, variance=0.00518269) with flow),
#   'pf_dsa_mu_lj_pfMuon_min_dxy_XLowRange': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(100, 0, 0.1, name='PF $\\mu$- type LJ PF $\\mu$ min dxy (cm)'),
#     storage=Weight()) # Sum: WeightedSum(value=0.335114, variance=0.00010525) (WeightedSum(value=0.403268, variance=0.000126655) with flow),
#   'mu_lj_muonN': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='mu_ljs_muon_n', label='$\\mu$-type Lepton Jet muon_n'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_pfMu_n': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='mu_ljs_pfMu_n', label='$\\mu$-type Lepton Jet pfMu_n'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_dsaMu_n': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(10, 0, 10, name='mu_ljs_dsaMu_n', label='$\\mu$-type Lepton Jet dsaMu_n'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_pfMu_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=33.4549, variance=0.0105072),
#   'mu_lj_pfMu_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=33.4549, variance=0.0105072),
#   'mu_lj_pfMu_nTrackerLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ nTrackerLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=33.4549, variance=0.0105072),
#   'mu_lj_pfMu_nStations': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ nStations'),
#     storage=Weight()) # Sum: WeightedSum(value=33.4549, variance=0.0105072),
#   'pf_mu_lj_pfMu_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=33.0051, variance=0.010366),
#   'pf_mu_lj_pfMu_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=33.0051, variance=0.010366),
#   'pf_dsa_mu_lj_pfMu_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.44975, variance=0.000141254),
#   'pf_dsa_mu_lj_pfMuon_min_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ min trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'pf_dsa_mu_lj_pfMuon_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'pf_dsa_mu_lj_pfMu_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=0.44975, variance=0.000141254),
#   'pf_mu_lj_pfMuon_min_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ min trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5016, variance=0.00518269),
#   'pf_mu_lj_pfMuon_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5016, variance=0.00518269),
#   'pf_mu_lj_pfMuon_min_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ min trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5016, variance=0.00518269),
#   'pf_mu_lj_pfMuon_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5016, variance=0.00518269),
#   'mu_lj_pfMu_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_min_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ min trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_min_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ min trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_min_nTrackerLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ min nTrackerLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_max_nTrackerLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ max nTrackerLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_trkNumTrkLayers_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ trkNumTrkLayers'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=33.4549, variance=0.0105072),
#   'mu_lj_pfMu_max_trkNumTrkLayers_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_min_trkNumTrkLayers_min_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ min trkNumTrkLayers'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF $\\mu$ min trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'pf_mu_lj_pfMuon_max_trkNumTrkLayers_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     Regular(40, 0, 40, name='PF $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5016, variance=0.00518269),
#   'pf_dsa_mu_lj_pfMu_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'pf_dsa_mu_lj_pfMu_min_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ min trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'pf_dsa_mu_lj_pfMuon_max_trkNumTrkLayers_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     Regular(40, 0, 40, name='PF-DSA $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'mu_lj_pfMu_trkNumTrkLayers_leading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF leading $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_trkNumTrkLayers_subleading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF subleading $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5409, variance=0.00519502),
#   'mu_lj_pfMu_trkNumTrkPixelHits_subleading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF subleading $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5409, variance=0.00519502),
#   'mu_lj_pfMu_trkNumTrkPixelHits_leading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF leading $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9049, variance=0.00530935),
#   'mu_lj_pfMu_trkNumTrkPixelHits_leading_subleading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF leading $\\mu$ trkNumPixelHits'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF subleading $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5409, variance=0.00519502),
#   'mu_lj_pfMu_trkNumTrkLayers_leading_subleading': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF leading $\\mu$ trkNumTrkLayers'),
#     Regular(20, 0, 20, name='$\\mu$- type LJ PF  subleading $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5409, variance=0.00519502),
#   'mu_lj_muon_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ  $\\mu$ trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=33.9003, variance=0.0106471),
#   'mu_lj_muon_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_muon_min_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ PF $\\mu$ min trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_muon_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ  $\\mu$ trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=33.9003, variance=0.0106471),
#   'mu_lj_muon_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'mu_lj_muon_min_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='$\\mu$- type LJ $\\mu$ min trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.909, variance=0.00531063),
#   'leading_mu_lj_muon_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading $\\mu$- type LJ $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'leading_mu_lj_dsaMu_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading $\\mu$- type LJ dsa $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.406723, variance=0.00012774),
#   'leading_pf_mu_lj_pfMu_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading PF $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5007, variance=0.0051824),
#   'leading_pf_dsa_mu_lj_pfMu_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='leading PF $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655),
#   'leading_mu_lj_pfMu_max_trkNumPixelHits': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading $\\mu$- type LJ PF $\\mu$ max trkNumPixelHits'),
#     storage=Weight()) # Sum: WeightedSum(value=16.904, variance=0.00530905),
#   'leading_mu_lj_muon_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading $\\mu$- type LJ $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.9074, variance=0.00531014),
#   'leading_mu_lj_pfMu_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.904, variance=0.00530905),
#   'leading_pf_mu_lj_pfMu_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='Leading PF $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=16.5007, variance=0.0051824),
#   'leading_pf_dsa_mu_lj_pfMu_max_trkNumTrkLayers': Hist(
#     StrCategory(['base_ljObjCut_ljIso_2lj'], name='channel'),
#     Regular(40, 0, 40, name='leading PF $\\mu$- type LJ PF $\\mu$ max trkNumTrkLayers'),
#     storage=Weight()) # Sum: WeightedSum(value=0.403268, variance=0.000126655)},
#  'counters': {'0.4': {'base_ljObjCut_ljIso_2lj': {'Total LJs': 108151,
#     'Gen As to muons': 53833,
#     'Gen As to electrons': 53833,
#     'Matched gen As to muons': 53833,
#     'Matched gen As to electrons': 53804}}},
#  'metadata': {'n_evts': 190498, 'scaled_sum_weights': 190498.0}}

# %%
QCD=[ 
     "QCD_Pt15To20", 
     "QCD_Pt20To30",
     "QCD_Pt30To50",
     "QCD_Pt50To80",
     "QCD_Pt80To120",
     "QCD_Pt120To170",
    "QCD_Pt170To300",
    "QCD_Pt300To470",
     "QCD_Pt470To600",
     "QCD_Pt600To800",
    "QCD_Pt800To1000",
     "QCD_Pt1000",
    ]
DY = [ 
    "DYJetsToMuMu_M10to50",
     # "DYJetsToMuMu_M50",
     ]
TT = [ 
     "TTJets",
     ]

bgs= QCD + DY + TT

# %%
def sum_bgs_hist(bgs_list, histogram_name, channel_name):
    """
    Sum histograms for a list of backgrounds.
    """
    summed_hist = None
    
    for x in bgs_list:
        print(x)
        output_bg = coffea.util.load(f"output_{x}{channel_name}.coffea")
        hist = output_bg["out"][x]["hists"][histogram_name][channel_name, ::4j]
        
        if summed_hist is None:
            summed_hist = hist.copy()
        else:
            summed_hist += hist
    
    return summed_hist

# %%
label_list =[]
histogram_name = "mu_lj_pfMuon_min_dxy_XLowRange"
channel_name = "base_ljObjCut_ljIso_2lj"
sum_bg = sum_bgs_hist(bgs, histogram_name,channel_name )
plt.figure(figsize=(12, 10))
for s in S:
    histogram = output_signal["out"][s]["hists"][histogram_name][channel_name, ::4j]
    parts = s.split("_")
    mass = parts[1]
    zd_mass = parts[2].replace("p", ".")
    ctau = parts[3].replace("p", ".").replace("mm", "")
    label = mass + ", "  + zd_mass + ", " + ctau + "mm"
    label_list.append(label)
    utilities.plot(histogram, flow ="none", yerr=True)
utilities.plot(sum_bg, yerr=True, flow=None)
plt.yscale("log")

plt.legend(label_list + ["Background"])
# Out:
# QCD_Pt15To20
# QCD_Pt20To30
# QCD_Pt30To50
# QCD_Pt50To80
# QCD_Pt80To120
# QCD_Pt120To170
# QCD_Pt170To300
# QCD_Pt300To470
# QCD_Pt470To600
# QCD_Pt600To800
# QCD_Pt800To1000
# QCD_Pt1000
# DYJetsToMuMu_M10to50
# TTJets

# %%
label_list =[]
histogram_name = "pf_mu_lj_pfMuon_min_dxy_XLowRange"
channel_name = "base_ljObjCut_ljIso_2lj"
sum_bg = sum_bgs_hist(bgs, histogram_name,channel_name )
plt.figure(figsize=(12, 10))
for s in S:
    histogram = output_signal["out"][s]["hists"][histogram_name][channel_name, ::4j]
    parts = s.split("_")
    mass = parts[1]
    zd_mass = parts[2].replace("p", ".")
    ctau = parts[3].replace("p", ".").replace("mm", "")
    label = mass + ", "  + zd_mass + ", " + ctau + "mm"
    label_list.append(label)
    utilities.plot(histogram, flow ="none", yerr=True)
utilities.plot(sum_bg, yerr=True, flow=None)
plt.yscale("log")

plt.legend(label_list + ["Background"])
# Out:
# QCD_Pt15To20
# QCD_Pt20To30
# QCD_Pt30To50
# QCD_Pt50To80
# QCD_Pt80To120
# QCD_Pt120To170
# QCD_Pt170To300
# QCD_Pt300To470
# QCD_Pt470To600
# QCD_Pt600To800
# QCD_Pt800To1000
# QCD_Pt1000
# DYJetsToMuMu_M10to50
# TTJets

# %%
label_list =[]
histogram_name = "pf_dsa_mu_lj_pfMuon_min_dxy_XLowRange"
channel_name = "base_ljObjCut_ljIso_2lj"
sum_bg = sum_bgs_hist(bgs, histogram_name,channel_name )
plt.figure(figsize=(12, 10))
for s in S:
    histogram = output_signal["out"][s]["hists"][histogram_name][channel_name, ::4j]
    parts = s.split("_")
    mass = parts[1]
    zd_mass = parts[2].replace("p", ".")
    ctau = parts[3].replace("p", ".").replace("mm", "")
    label = mass + ", "  + zd_mass + ", " + ctau + "mm"
    label_list.append(label)
    utilities.plot(histogram, flow ="none", yerr=True)
utilities.plot(sum_bg, yerr=True, flow=None)
plt.yscale("log")

plt.legend(label_list + ["Background"])
# Out:
# QCD_Pt15To20
# QCD_Pt20To30
# QCD_Pt30To50
# QCD_Pt50To80
# QCD_Pt80To120
# QCD_Pt120To170
# QCD_Pt170To300
# QCD_Pt300To470
# QCD_Pt470To600
# QCD_Pt600To800
# QCD_Pt800To1000
# QCD_Pt1000
# DYJetsToMuMu_M10to50
# TTJets
