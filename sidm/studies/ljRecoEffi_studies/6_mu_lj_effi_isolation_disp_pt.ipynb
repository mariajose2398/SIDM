# %%
#### python
import os
import sys
import importlib
# columnar analysis
from coffea import processor
from coffea.nanoevents import NanoAODSchema
import awkward as ak
from dask.distributed import Client, performance_report
# local
sidm_path = str(os.getcwd()).split("/sidm")[0]
if sidm_path not in sys.path: sys.path.insert(1, sidm_path)
from sidm.tools import utilities, sidm_processor, scaleout, llpnanoaodschema
# always reload local modules to pick up changes during development
importlib.reload(utilities)
importlib.reload(sidm_processor)
importlib.reload(scaleout)
# plotting
import matplotlib.pyplot as plt
utilities.set_plot_style()
# %matplotlib inline
import coffea.util
import mplhep as hep

# %%
# client = scaleout.make_dask_client("tls://localhost:8786")
# client

from distributed import LocalCluster, Client

cluster = LocalCluster()
cluster.scale(16)  # create 4 local workers
client = Client(cluster)

# %%
runner = processor.Runner(
    # executor=processor.IterativeExecutor(),
    executor=processor.DaskExecutor(client=client),
    # schema=NanoAODSchema,
    schema = llpnanoaodschema.LLPNanoAODSchema,
    #maxchunks=1,
    skipbadfiles=True,
)
channels = [
    # "baseNoLj", 
    "baseNoLj_A_mumu", 
    "baseNoLj_A_mumu_matched_lj",
    "baseNoLj_A_mumu_matched_lj_iso",
    "baseNoLj_A_mumu_matched_lj_iso_disp"
    
    
        
           ]

p = sidm_processor.SidmProcessor(
    channels,
    ["lj_reco_effi_base", ],
)

# %%
samples = [

     '2Mu2E_500GeV_0p25GeV_4p0mm',
     '2Mu2E_500GeV_1p2GeV_19p0mm',
     '2Mu2E_500GeV_5p0GeV_80p0mm',
     

    
]
fileset = utilities.make_fileset(samples, "llpNanoAOD_v2", max_files=-1, location_cfg="signal_2mu2e_v10.yaml", replace_xcache=True)

                            

output_signal = runner.run(fileset, treename="Events", processor_instance=p)
# Out:
# [                                        ] | 0% Completed | 10.1s0s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# [                                        ] | 0% Completed | 10.4s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 0% Completed | 10.7s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 0% Completed | 11.3s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 0% Completed | 11.6s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 0% Completed | 12.1s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 0% Completed | 13.3s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 13.8s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 14.0s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 14.2s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 14.6s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 14.9s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 15.1s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 15.4s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 15.6s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 15.9s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# /home/mariaj-cern/.local/lib/python3.12/site-packages/awkward/_nplikes/array_module.py:292: RuntimeWarning: invalid value encountered in divide
#   return impl(*broadcasted_args, **(kwargs or {}))
# [                                        ] | 0% Completed | 31.4s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 31.6s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 32.2s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 32.3s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 32.6s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 33.2s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 34.3s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# #--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 34.9s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 35.0s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 36.3s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 36.4s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 36.7s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 36.8s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 37.0s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 0% Completed | 37.1s#--------------------------------------------------------------------------
# #                         FastJet release 3.4.3
# #                 M. Cacciari, G.P. Salam and G. Soyez
# #     A software package for jet finding and analysis at colliders
# #                           http://fastjet.fr
# #
# # Please cite EPJC72(2012)1896 [arXiv:1111.6097] if you use this package
# # for scientific work and optionally PLB641(2006)57 [hep-ph/0512210].
# #
# # FastJet is provided without warranty under the GNU GPL v2 or higher.
# # It uses T. Chan's closest pair algorithm, S. Fortune's Voronoi code,
# # CGAL and 3rd party plugin jet algorithms. See COPYING file for details.
# #--------------------------------------------------------------------------
# [                                        ] | 1% Completed | 48.2s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [                                        ] | 2% Completed |  1min  4.9s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#                                       ] | 2% Completed |  1min 10.7s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#                                       ] | 3% Completed |  1min 20.5s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#                                       ] | 4% Completed |  1min 23.5s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#                                       ] | 4% Completed |  1min 47.1s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [##                                      ] | 6% Completed |  2min  8.8s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [##                                      ] | 7% Completed |  2min 25.6s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [##                                      ] | 7% Completed |  2min 28.7s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [####                                    ] | 10% Completed |  2min 49.9s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#####                                   ] | 14% Completed |  2min 54.3s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [######                                  ] | 16% Completed |  2min 56.2s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#######                                 ] | 18% Completed |  2min 56.8s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#########                               ] | 22% Completed |  2min 59.0s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# [#################                       ] | 43% Completed |  3min  2.8s
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_electronIdx => Electron
#   warnings.warn(
# /home/mariaj-cern/.local/lib/python3.12/site-packages/coffea/nanoevents/schemas/nanoaod.py:264: RuntimeWarning: Missing cross-reference index for LowPtElectron_photonIdx => Photon
#   warnings.warn(
# 2Mu2E_500GeV_0p25GeV_4p0mm is simulation. Scaling histograms or cutflows according to lumi*xs.
# Ignoring signal cross sections, assuming 1 fb
# 2Mu2E_500GeV_5p0GeV_80p0mm is simulation. Scaling histograms or cutflows according to lumi*xs.
# Ignoring signal cross sections, assuming 1 fb
# 2Mu2E_500GeV_1p2GeV_19p0mm is simulation. Scaling histograms or cutflows according to lumi*xs.
# Ignoring signal cross sections, assuming 1 fb
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 15
#      11
#      12
#      13
#      14 output_signal = runner.run(fileset, treename="Events", processor_instance=p)
# ---> 15 coffea.util.save(output_signal, "output_files/output_signal_effi_muons_lxy.coffea"  )
#
# File ~/.local/lib/python3.12/site-packages/coffea/util.py:49, in save(output, filename)
#      44 def save(output, filename):
#      45     """Save a coffea object or collection thereof to disk
#      46
#      47     This function can accept any picklable object.  Suggested suffix: ``.coffea``
#      48     """
# ---> 49     with lz4.frame.open(filename, "wb") as fout:
#      50         thepickle = cloudpickle.dumps(output)
#      51         fout.write(thepickle)
#
# File /work/users/mariaj-cern/SIDM/.pixi/envs/default/lib/python3.12/site-packages/lz4/frame/__init__.py:878, in open(filename, mode, encoding, errors, newline, block_size, block_linked, compression_level, content_checksum, block_checksum, auto_flush, return_bytearray, source_size)
#     874         raise ValueError("Argument 'newline' not supported in binary mode")
#     876 _mode = mode.replace('t', '')
# --> 878 binary_file = LZ4FrameFile(
#     879     filename,
#     880     mode=_mode,
#     881     block_size=block_size,
#     882     block_linked=block_linked,
#     883     compression_level=compression_level,
#     884     content_checksum=content_checksum,
#     885     block_checksum=block_checksum,
#     886     auto_flush=auto_flush,
#     887     return_bytearray=return_bytearray,
#     888     source_size=source_size,
#     889 )
#     891 if 't' in mode:
#     892     return io.TextIOWrapper(binary_file, encoding, errors, newline)
#
# File /work/users/mariaj-cern/SIDM/.pixi/envs/default/lib/python3.12/site-packages/lz4/frame/__init__.py:530, in LZ4FrameFile.__init__(self, filename, mode, block_size, block_linked, compression_level, content_checksum, block_checksum, auto_flush, return_bytearray, source_size)
#     528 if 'b' not in mode:
#     529     mode += 'b'
# --> 530 self._fp = builtins.open(filename, mode)
#     531 self._closefp = True
#     532 self._mode = mode_code
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_files/output_signal_effi_muons_lxy.coffea'

# %%
coffea.util.save(output_signal, "output_files/output_signal_effi_muons_lxy.coffea"  )

# %%
hists = output_signal["out"]["2Mu2E_500GeV_0p25GeV_4p0mm"]["hists"]
ch1 = "baseNoLj_A_mumu"
ch2 = "baseNoLj_A_mumu_matched_lj"
ch3 = "baseNoLj_A_mumu_matched_lj_iso"
ch4 = "baseNoLj_A_mumu_matched_lj_iso_disp"

legend = [
r"$Z_d \rightarrow \mu\mu $",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso and Disp"
]
histogram = "genAs_toMu_pt_highRange"

num_list = [
          hists[histogram][ch2, :400j],
          hists[histogram][ch3, :400j],
         hists[histogram][ch4, :400j],
]
den = hists[histogram][ch1,:400j]

utilities.plot_ratio (num_list,den,legend =legend, text = "500GeV, 0.25GeV, 300 cm", ylabel = "Arbitrary Units")
folder_name = "plots/"
file_name = "2Mu2E_500GeV_0p25GeV_4p0mmgenAs_toMu_pt"
save_path = os.path.join(folder_name, file_name)         
    
plt.savefig(save_path)
# Out:
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()

# %%
hists = output_signal["out"]["2Mu2E_500GeV_1p2GeV_19p0mm"]["hists"]

legend = [
r"$Z_d \rightarrow \mu\mu $",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso and Disp"
]

histogram = "genAs_toMu_pt_highRange"
den = hists[histogram][ch1,:400j]
num_list = [
          hists[histogram][ch2, :400j],
          hists[histogram][ch3, :400j],
         hists[histogram][ch4, :400j],
]
utilities.plot_ratio (num_list,den,legend =legend, text = "500GeV, 1.2GeV, 300 cm", ylabel = "Arbitrary Units") 
folder_name = "plots/"
file_name = "2Mu2E_500GeV_1p2GeV_19p0mmgenAs_toMu_pt"
save_path = os.path.join(folder_name, file_name)     

plt.savefig(save_path)
# Out:
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()

# %%
hists = output_signal["out"]["2Mu2E_500GeV_5p0GeV_80p0mm"]["hists"]


legend = [
r"$Z_d \rightarrow \mu\mu $",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso",
r"$Z_d \rightarrow \mu\mu$ with $\mu$ LJ with Iso and Disp"
]
histogram = "genAs_toMu_pt_highRange"
num_list = [
          hists[histogram][ch2, :400j],
          hists[histogram][ch3, :400j],
         hists[histogram][ch4, :400j],
]
den = hists[histogram][ch1,:400j]
utilities.plot_ratio (num_list,den,legend =legend, text = "500GeV, 5GeV, 300 cm", ylabel = "Arbitrary Units")
folder_name = "plots/"
file_name = "2Mu2E_500GeV_5p0GeV_80p0mmgenAs_toMu_pt"
save_path = os.path.join(folder_name, file_name)

plt.savefig(save_path)
# Out:
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:190: RuntimeWarning: invalid value encountered in divide
#   eff_values = num_vals/denom_vals
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:195: RuntimeWarning: invalid value encountered in divide
#   num_counts = num_vals**2 / num_hist.variances()
# /work/users/mariaj-cern/SIDM/sidm/tools/utilities.py:196: RuntimeWarning: invalid value encountered in divide
#   denom_counts = denom_vals**2 / denom_hist.variances()
